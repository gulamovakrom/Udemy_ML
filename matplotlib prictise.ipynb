# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
heart_disease = pd.read_csv("heart-disease.csv")
over_50 = heart_disease[heart_disease["age"]>50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
plt.style.use('seaborn')
fig, (ax0,ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10),
                              sharex=True)
scatter = ax0.scatter(x=over_50["age"],
            y=over_50["chol"],
            c=over_50["target"],
             cmap="winter")
ax0.set(title="heart & Chol",
        ylabel="Chol")
ax0.legend(*scatter.legend_elements(),title="Target")
ax0.axhline(over_50["chol"].mean(),linestyle='--')
ax0.set_ylim([150,400])


scatter = ax1.scatter(x=over_50["age"],
                      y=over_50["thalach"],
                      c=over_50["target"],
                      cmap="winter")
ax1.set(title="heart & Chol",
        ylabel="Thalach")
ax1.legend(*scatter.legend_elements(),title="Target")
ax1.axhline(over_50["thalach"].mean(),linestyle='--')
ax1.set_ylim([0,250]),ax1.set_xlim([50,75])
fig.suptitle("Heart Disease Info", fontsize=16,fontweight="bold");

# %%
#plt.xlim(-10,10),plt.ylim(0,25)
#x=np.random.randn(10)
plt.axline((0, 0), (1, 1), linewidth=4, color='r')

# %%
np.random.seed(19680801)

# %%
t = np.arange(0.0, 10.0,0.001)

# %%
t
# Out:
# array([0.000e+00, 1.000e-03, 2.000e-03, ..., 9.997e+00, 9.998e+00,
#        9.999e+00])
