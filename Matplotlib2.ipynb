# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
heart_desease = pd.read_csv("heart-disease.csv")
heart_desease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
over_50 = heart_desease[heart_desease["age"]>50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
over_50.plot(x='age',y='chol',kind='scatter',figsize=(16,8),c='target',xlim=(50,60),ylim=(200,300),xlabel='age',ylabel='chol',title='Ohuenniy',)
ax.set_xlim(50,60)
ax.set_ylim(200,300);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2fb200fd50b9> in <module>
#       1 over_50.plot(x='age',y='chol',kind='scatter',figsize=(16,8),c='target',xlim=(50,60),ylim=(200,300),xlabel='age',ylabel='chol',title='Ohuenniy',)
# ----> 2 ax.set_xlim(50,60)
#       3 ax.set_ylim(200,300);
#
# NameError: name 'ax' is not defined

# %%
x = np.random.rand(10,4)
x
# Out:
# array([[0.00542507, 0.59247088, 0.47928258, 0.65073788],
#        [0.51371419, 0.3437132 , 0.29695192, 0.70802817],
#        [0.20457469, 0.87359691, 0.29697799, 0.55609299],
#        [0.2778643 , 0.2628795 , 0.58189485, 0.27295748],
#        [0.82662384, 0.42733318, 0.86525425, 0.99483789],
#        [0.74860449, 0.37533497, 0.47219278, 0.87427722],
#        [0.18693844, 0.45736292, 0.61469617, 0.45203586],
#        [0.4738879 , 0.47466805, 0.85729131, 0.334709  ],
#        [0.64520902, 0.77132556, 0.68620724, 0.90077425],
#        [0.43775322, 0.96245526, 0.52053987, 0.34180689]])

# %%
df = pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.005425  0.592471  0.479283  0.650738
# 1  0.513714  0.343713  0.296952  0.708028
# 2  0.204575  0.873597  0.296978  0.556093
# 3  0.277864  0.262879  0.581895  0.272957
# 4  0.826624  0.427333  0.865254  0.994838
# 5  0.748604  0.375335  0.472193  0.874277
# 6  0.186938  0.457363  0.614696  0.452036
# 7  0.473888  0.474668  0.857291  0.334709
# 8  0.645209  0.771326  0.686207  0.900774
# 9  0.437753  0.962455  0.520540  0.341807

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
over_50.plot(kind="scatter",figsize=(30,10),x="age",y="chol");

# %%
fig, ax = plt.subplots(nrows=2,
                       ncols=3,
                       figsize=(24,6))
ax[0,0].plot(x,x**2),ax[0,1].scatter(x,x**2),ax[0,2].hist([1,2,3],[2,5,9]);

# %%
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
# OO method from scatch
fig, ax = plt.subplots(figsize=(10,6))

# plot the data
scatter = ax.scatter(x=over_50["age"],
            y=over_50["chol"],
            c=over_50["target"])

# Customising data
ax.set(title="Heart Desease age per Cholestole",
       xlabel="Age",
       ylabel="Cholestrole")

# Add some legend
ax.legend(*scatter.legend_elements(),title="target")

# Add a horizontal line
ax.axhline(over_50["chol"].mean(), linestyle="--");

# %%
fig, (ax0,ax1) = plt.subplots(nrows=2,
                             ncols=1,
                             figsize=(10,10),
                             sharex=True)
scatter = ax0.scatter(x=over_50["age"],
                      y=over_50["chol"],
                      c=over_50["target"])
ax0.set(title="Heart Disease and cholestrol",
        ylabel="Cholestrol")
ax0.legend(*scatter.legend_elements(),title="Target")
ax0.axhline(over_50["chol"].mean(),linestyle="--")

scatter = ax1.scatter(x=over_50["age"],
                      y=over_50["thalach"],
                      c=over_50["target"])
ax1.set(title="Heart Disease and Thalach",
        xlabel="Age",
        ylabel="Thalach")
ax1.axhline(over_50["thalach"].mean(),linestyle="--")
ax1.legend(*scatter.legend_elements(),title="Target")

fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold");

# %% [markdown]
# ## Customising Matplotlib plots and getting stylish

# %%
# plt styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("seaborn-paper")
over_50["age"].plot();

# %%
fig
